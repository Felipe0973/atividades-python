# %% [markdown]
# <a href="https://colab.research.google.com/github/Felipe0973/atividades-python/blob/main/atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Atividade 1 introdução ao python

# %%
print("Ola mundo")
print("Curso técnico de informatica")
# Out:
# ola mundo
# curso técnico de informatica

# %%
disciplina=input("digite o nome da disciplina: ")
conteúdo=input("digite o conteúdo estudado: ")
atividade=input("digite o numero da atividade: ")
print("\n--- Informações da atividade ---")
print("disciplina: ",disciplina)
print("conteúdo: ",conteúdo)
print("atividade: ",atividade)
# Out:
# digite o nome da disciplina: matematica
# digite o conteúdo estudado: modulo
# digite o numero da atividade: 248
#
# --- Informações da atividade ---
# disciplina:  matematica
# conteúdo:  modulo
# atividade:  248
